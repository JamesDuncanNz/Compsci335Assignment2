# %% [markdown]
# <a href="https://colab.research.google.com/github/JamesDuncanNz/Compsci335Assignment2/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Authentication to GCP

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# Setup Env

# %%
project_id = 'gcp-demos-229619'

# %% [markdown]
# Query BQ

# %% [markdown]
# # **Notes:**
#
# What can affect a players game play and points
#
# ##**Table 17_18_playerBoxScore**
#
# **Features**
#
# * teamLoc Away vs home
# * teamDayOff (Lower the better)
# * playStat (Bench, Starter)
# * playMin
# * playPos
# * opptAbbr
# * opptDayOff
#
# **Filters**
#
# * seasTyp
# * Joins
# * stDate
# * teamAbbr
#
# ##**Table 17_18_standings **
#
# **Features**
#
# * stDate
# * rank
# * gameWon
# * gameLost
# * stk (Win)
# * stktype (Higher the better)
# * homeWin
# * homeLoss
# * awayWin
# * sos (Strength of schedule)

# %%
from google.cloud import bigquery

client = bigquery.Client(project=project_id)

sample_count = 2000
query = client.query('''
SELECT * FROM `gcp-demos-229619.nbastats.17_18_standings` 
''').to_dataframe()



print(query)
# Out:
#           stDate teamAbbr  rank rankOrd  gameWon  gameLost stk stkType  \
# 0     2017-10-17       GS    15    15th        0         1  L1    loss
# 1     2017-10-18       GS     9     9th        0         1  L1    loss
# 2     2017-10-19       GS     8     8th        0         1  L1    loss
# 3     2017-10-20       GS     7     7th        1         1  W1     win
# 4     2017-10-21       GS    11    11th        1         2  L1    loss
# 5     2017-10-22       GS     9     9th        1         2  L1    loss
# 6     2017-10-23       GS     8     8th        2         2  W1     win
# 7     2017-10-24       GS     6     6th        2         2  W1     win
# 8     2017-10-25       GS     6     6th        3         2  W2     win
# 9     2017-10-26       GS     5     5th        3         2  W2     win
# 10    2017-10-27       GS     5     5th        4         2  W3     win
# 11    2017-10-28       GS     5     5th        4         2  W3     win
# ...
